# %%
# 데이터 로드
import pandas as pd

log19 = pd.read_csv('data/공공자전거_대여이력_정보/rental_data_2019.csv', encoding='cp949', index_col=0)
log20 = pd.read_csv('data/공공자전거_대여이력_정보/rental_data_2020.csv', encoding='cp949', index_col=0)
log21 = pd.read_csv('data/공공자전거_대여이력_정보/rental_data_2021.csv', encoding='cp949', index_col=0)

ride19 = pd.read_csv('data/공공자전거_이용정보(시간대별)/ride_data_2019.csv', encoding='cp949', index_col=0)
ride20 = pd.read_csv('data/공공자전거_이용정보(시간대별)/ride_data_2020.csv', encoding='cp949', index_col=0)
ride21 = pd.read_csv('data/공공자전거_이용정보(시간대별)/ride_data_2021.csv', encoding='cp949', index_col=0)
# Out:
# C:\Users\jomin\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\jomin\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# 대여이력 및 이용정보 로드 확인
log19.head()
# Out:
#      bike_no          rental_date  rental_loc_no    rental_loc_name  \
# 0  SPB-10632  2019-01-01 00:00:44           1421           신내역 4번출구
# 1  SPB-10957  2019-01-01 00:02:16           1408         먹골역 6번출구 앞
# 2  SPB-16067  2019-01-01 00:04:12            347  동대문역사문화공원역 9번출구 앞
# 3  SPB-17170  2019-01-01 00:03:09            615   용두동 래미안허브리츠아파트 앞
# 4  SPB-14130  2019-01-01 00:01:44           1177             수명중?고교
#
#    rental_rack          return_date  return_loc_no return_loc_name  \
# 0            3  2019-01-01 00:03:53           1420        신내어울공원 앞
# 1            3  2019-01-01 00:07:07           1433        중화역 2번출구
# 2           17  2019-01-01 00:07:07            387      훈련원공원주차장 앞
# 3            4  2019-01-01 00:07:27            612    시립동부병원 앞 사거리
# 4            7  2019-01-01 00:08:09           1152          마곡역교차로
#
#    return_rack  rental_time  rental_distance
# 0           13            2            580.0
# 1            4            4           1020.0
# ...

# %%
ride19.head()
# Out:
#          date  time  location_num     location_name rental_code sex   age  \
# 0  2019-01-01     0           458    458. 광화문역 5번출구         정기권   F  ~10대
# 1  2019-01-01     0          2159        2159. 인헌초교         정기권   F   20대
# 2  2019-01-01     0          1362   1362. 보문역6번출구 앞         정기권   F   20대
# 3  2019-01-01     0          3106   3106. 홍남교 두바퀴쉼터         정기권   F   20대
# 4  2019-01-01     0           118  118. 광흥창역 2번출구 앞         정기권   F   20대
#
#    usage calories carbon  distance  usage_time
# 0      1    41.96   0.38    1630.0          29
# 1      1    27.23   0.29    1250.0           7
# 2      1    20.18   0.23     980.0           5
# 3      1     7.48    0.1     420.0           4
# 4      1     25.7   0.26    1100.0           7

# %%
display(log19.info())
display(log20.info())
display(log21.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18485953 entries, 0 to 18485952
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   bike_no          object
#  1   rental_date      object
#  2   rental_loc_no    int64
#  3   rental_loc_name  object
#  4   rental_rack      int64
#  5   return_date      object
#  6   return_loc_no    int64
#  7   return_loc_name  object
#  8   return_rack      int64
#  9   rental_time      int64
#  10  rental_distance  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 1.7+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17421645 entries, 0 to 17421644
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   bike_no          object
#  1   rental_date      object
#  2   rental_loc_no    int64
#  3   rental_loc_name  object
#  4   rental_rack      object
#  5   return_date      object
#  6   return_loc_no    object
# ...

# %%
# 컬럼별 누락값 확인 - 대여이력
display(log19.isnull().sum())
display(log20.isnull().sum())
display(log21.isnull().sum())
# Out:
# bike_no            0
# rental_date        0
# rental_loc_no      0
# rental_loc_name    0
# rental_rack        0
# return_date        0
# return_loc_no      0
# return_loc_name    0
# return_rack        0
# rental_time        0
# rental_distance    0
# dtype: int64
# bike_no              0
# rental_date          0
# rental_loc_no        0
# rental_loc_name      0
# rental_rack          0
# return_date          0
# return_loc_no        0
# return_loc_name      0
# return_rack          0
# rental_time          0
# rental_distance    107
# dtype: int64
# bike_no            0
# rental_date        0
# rental_loc_no      0
# rental_loc_name    0
# rental_rack        0
# return_date        0
# return_loc_no      0
# return_loc_name    0
# return_rack        0
# rental_time        0
# rental_distance    0
# dtype: int64

# %%
# 컬럼별 누락값 확인 - 이용정보
display(ride19.isnull().sum())
display(ride20.isnull().sum())
display(ride21.isnull().sum())
# Out:
# date                   0
# time                   0
# location_num           0
# location_name          0
# rental_code            0
# sex              7392324
# age                    0
# usage                  0
# calories               0
# carbon                 0
# distance               0
# usage_time             0
# dtype: int64
# date                   0
# time                   0
# location_num           0
# location_name          0
# rental_code            0
# sex              9495988
# age                    0
# usage                  0
# calories               0
# carbon                 0
# distance               0
# usage_time             0
# dtype: int64
# date                  0
# time                  0
# location_num          0
# location_name         0
# rental_code           0
# sex              317622
# age                   0
# usage                 0
# calories              0
# carbon                0
# distance              0
# usage_time            0
# ...

# %% [markdown]
# ### 20년 데이터 확인

# %%
# 대여이력 테이블의 결측치는 구분자 ',' 때문에 데이터가 밀리며 발생한 것으로 추정
log20[log20.isnull().any(axis=1)]
# Out:
#            bike_no          rental_date  rental_loc_no rental_loc_name  \
# 47219    SPB-09846  2020-01-03 06:51:33           1162   공항초등학교?풍覺?,8"
# 62366    SPB-02297  2020-01-03 17:37:10           1428          원묵고등학교
# 64023    SPB-16990  2020-01-03 18:11:04           1986         태평양물산빌딩
# 81098    SPB-12017  2020-01-04 11:38:07           3509   세종사이?測淪閨?,11"
# 203377   SPB-07700  2020-01-10 17:24:40           1984        구?慣맡?,7"
# ...            ...                  ...            ...             ...
# 5599910  SPB-33100  2020-05-07 06:54:00           2054           삼익아파트
# 5718158  SPB-33891  2020-05-08 15:39:00            470    회현역 7번?瘦?,0"
# 5774659  SPB-32882  2020-05-10 15:36:00            575       중앙농협 중곡지점
# 5801727  SPB-03653  2020-05-10 20:33:00            103      망원역 2번출구 앞
# 5930630  SPB-02909  2020-05-12 17:53:00           2020    장승배기역2번출구뒷편쪽
#
#                  rental_rack          return_date  return_loc_no  \
# ...

# %%
# 특정월의 데이터셋 문제인지 확인
log20['year_month'] = log20.rental_date.map(lambda x: x[:7])
log20.year_month.value_counts()
# Out:
# 2020-10    2869182
# 2020-04    2086362
# 2020-11    1975137
# 2020-06    1755046
# 2020-03    1476324
# 2020-07    1353719
# 2020-09    1273048
# 2020-12    1185907
# 2020-05    1046658
# 2020-08     900358
# 2020-01     765611
# 2020-02     734293
# Name: year_month, dtype: int64

# %%
# 2020년 1~5월 데이터에서 발생함
log20[log20.isnull().any(axis=1)].year_month.value_counts()
# Out:
# 2020-04    31
# 2020-03    28
# 2020-05    18
# 2020-02    16
# 2020-01    14
# Name: year_month, dtype: int64

# %%
# 21년 데이터는 컴마와 상관없이 잘 불러와짐
log21[log21.rental_loc_name.map(lambda x: '염창역 3, 4번' in x)]
# Out:
#           bike_no          rental_date  rental_loc_no  rental_loc_name  \
# 265807  SPB-53060  2021-01-01 13:35:33            773  염창역 3, 4번 출구 사이
# 265808  SPB-50486  2021-01-01 13:36:45            773  염창역 3, 4번 출구 사이
# 265809  SPB-31685  2021-01-01 14:07:18            773  염창역 3, 4번 출구 사이
# 265810  SPB-52576  2021-01-01 14:52:34            773  염창역 3, 4번 출구 사이
# 265811  SPB-52086  2021-01-01 16:40:44            773  염창역 3, 4번 출구 사이
# ...           ...                  ...            ...              ...
# 266271  SPB-52520  2021-01-31 19:20:50            773  염창역 3, 4번 출구 사이
# 266272  SPB-31003  2021-01-31 21:44:18            773  염창역 3, 4번 출구 사이
# 266273  SPB-40468  2021-01-31 21:22:15            773  염창역 3, 4번 출구 사이
# 266274  SPB-32932  2021-01-31 21:38:38            773  염창역 3, 4번 출구 사이
# 266275  SPB-42916  2021-01-31 23:26:51            773  염창역 3, 4번 출구 사이
#
#         rental_rack          return_date  return_loc_no     return_loc_name  \
# ...

# %%
ride20[ride20.isnull().any(axis=1)]
# Out:
#                 date  time  location_num                location_name  \
# 0         2020-01-01     0          1044                  1044. 굽은다리역
# 1         2020-01-01     0          1656           1656. 중앙하이츠 아파트 입구
# 2         2020-01-01     0          1337                 1337. 돈암성당 옆
# 3         2020-01-01     0          1984                   1984. 구로구청
# 4         2020-01-01     0          2601             2601. 석촌호수 서호사거리
# ...              ...   ...           ...                          ...
# 19026005  2020-12-31    23          1019  1019. 다성이즈빌아파트(호원대 대각선 맞은편)
# 19026006  2020-12-31    23          1332           1332. 석계역 5번출구 건너편
# 19026007  2020-12-31    23          2102                2102. 봉림교 교통섬
# 19026008  2020-12-31    23          1008        1008. 암사역 3번출구(국민은행앞)
# 19026034  2020-12-31    23           419                  419. 홈플러스 앞
#
#          rental_code  sex   age  usage calories carbon  distance  usage_time
# ...

# %%
ride20.sex.isnull().sum()
# Out:
# 9495988

# %%
# 성별속성 절반 가량 결측
ride20.sex.isnull().mean()
# Out:
# 0.4991049369981712

# %%
# 성별 대소문자 구분되어있음 -> 전처리 함수 반영 필요
ride20.sex.value_counts()
# Out:
# M    5788591
# F    3733586
# m       4823
# f       3047
# Name: sex, dtype: int64

# %%
import pandas as pd

# %% [markdown]
# # 공공자전거 대여이력 정보

# %% [markdown]
# ## 1. data

# %%
rental_19_01 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.01.csv", encoding='cp949')
rental_19_02 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.02.csv", encoding='cp949')

# rental_19_03, rental_19_04는 컬럼명 부재, 직접 입력 필요
rental_19_03 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.03.csv", encoding='cp949')
rental_19_04 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.04.csv", names = ['자전거번호', '대여일시', '대여 대여소번호', '대여 대여소명', '대여거치대', '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'], header = None, encoding='cp949')

rental_19_05 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.05.csv", names = ['자전거번호', '대여일시', '대여 대여소번호', '대여 대여소명', '대여거치대', '반납일시', '반납대여소번호', '반납대여소명', '반납거치대', '이용시간', '이용거리'], header = None, encoding='cp949')
rental_19_06_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.06_1.csv", encoding='cp949')
rental_19_06_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.06_2.csv", encoding='cp949')
rental_19_06_3 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.06_3.csv", encoding='cp949')
rental_19_07_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.07_1.csv", encoding='cp949')
rental_19_07_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.07_2.csv", encoding='cp949')
rental_19_07_3 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.07_3.csv", encoding='cp949')
rental_19_08_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.08_1.csv", encoding='cp949')
rental_19_08_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.08_2.csv", encoding='cp949')
rental_19_08_3 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.08_3.csv", encoding='cp949')
rental_19_09_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.09_1.csv", encoding='cp949')
rental_19_09_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.09_2.csv", encoding='cp949')
rental_19_09_3 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.09_3.csv", encoding='cp949')
rental_19_10_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.10_1.csv", encoding='cp949')
rental_19_10_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.10_2.csv", encoding='cp949')
rental_19_10_3 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.10_3.csv", encoding='cp949')
rental_19_11_1 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.11_1.csv", encoding='cp949')
rental_19_11_2 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.11_2.csv", encoding='cp949')
rental_19_12 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2019.12.csv", encoding='cp949')
rental_20_01 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.01.csv", encoding='cp949')
rental_20_02 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.02.csv", encoding='cp949')
rental_20_03 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.03.csv", encoding='cp949')
rental_20_04 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.04.csv", encoding='cp949')
rental_20_05 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.05.csv")
rental_20_06 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.06.csv", encoding='cp949')
rental_20_0708 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.07_08.csv", encoding='cp949')
rental_20_09 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.09.csv", encoding='cp949')
rental_20_10 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.10.csv", encoding='cp949')
rental_20_11 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.11.csv", encoding='cp949')
rental_20_12 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2020.12.csv", encoding='cp949')
rental_21_01 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/공공자전거 대여이력 정보_2021.01.csv", encoding='cp949')
# Out:
# /Users/hyomin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## 2. column name 확인

# %%
rental_dataset = [rental_19_01, rental_19_02, rental_19_03, rental_19_04, rental_19_05, rental_19_06_1,
                    rental_19_06_2, rental_19_06_3, rental_19_07_1, rental_19_07_2, rental_19_07_3, 
                    rental_19_08_1, rental_19_08_2, rental_19_08_3, rental_19_09_1, rental_19_09_2, rental_19_09_3,
                    rental_19_10_1, rental_19_10_2, rental_19_10_3, rental_19_11_1, rental_19_11_2, rental_19_12,
                    rental_20_01, rental_20_02, rental_20_03, rental_20_04, rental_20_05, rental_20_06,
                    rental_20_0708, rental_20_09, rental_20_10, rental_20_11, rental_20_12, rental_21_01]

# %%
for i in rental_dataset:
    print(i.columns[0:])

# %% [markdown]
# ## 3. date

# %%
for i in rental_dataset:
    i['대여일시'] = pd.to_datetime(i["대여일시"])
# Out:
#                  대여일시
# 0 2019-01-01 00:00:44
# 1 2019-01-01 00:02:16
# 2 2019-01-01 00:04:12
#                       대여일시
# 485698 2019-01-31 23:43:55
# 485699 2019-01-31 23:30:39
# 485700 2019-01-31 19:41:46
#                  대여일시
# 0 2019-02-01 00:00:46
# 1 2019-02-01 00:00:52
# 2 2019-02-01 00:00:11
#                       대여일시
# 461969 2019-02-28 23:00:55
# 461970 2019-02-28 11:10:34
# 461971 2019-02-28 17:42:04
#                  대여일시
# 0 2019-03-01 00:00:04
# 1 2019-03-01 00:00:43
# 2 2019-03-01 00:02:45
#                       대여일시
# 885133 2019-03-31 21:50:16
# 885134 2019-03-31 07:35:10
# 885135 2019-03-31 22:09:01
#                  대여일시
# 0 2019-04-01 00:00:07
# 1 2019-04-01 00:02:10
# 2 2019-04-01 00:02:24
#                        대여일시
# 1427764 2019-04-30 23:31:31
# 1427765 2019-04-30 21:53:10
# 1427766 2019-04-30 22:57:56
#                  대여일시
# 0 2019-05-01 00:01:07
# 1 2019-05-01 00:03:06
# 2 2019-05-01 00:00:22
#                        대여일시
# ...

# %%
for i in rental_dataset:
    i = i.sort_values("대여일시")
    print(i.iloc[:,[1]].head(3))
    print(i.iloc[:,[1]].tail(3))
# Out:
#                   대여일시
# 70 2019-01-01 00:00:01
# 34 2019-01-01 00:00:07
# 0  2019-01-01 00:00:44
#                       대여일시
# 485666 2019-01-31 23:59:36
# 485680 2019-01-31 23:59:40
# 485652 2019-01-31 23:59:49
#                   대여일시
# 98 2019-02-01 00:00:08
# 2  2019-02-01 00:00:11
# 16 2019-02-01 00:00:21
#                       대여일시
# 461898 2019-02-28 23:59:54
# 461744 2019-02-28 23:59:57
# 461805 2019-02-28 23:59:59
#                    대여일시
# 0   2019-03-01 00:00:04
# 15  2019-03-01 00:00:07
# 211 2019-03-01 00:00:19
#                       대여일시
# 885050 2019-03-31 23:59:54
# 885013 2019-03-31 23:59:59
# 884958 2019-03-31 23:59:59
#                   대여일시
# 0  2019-04-01 00:00:07
# 9  2019-04-01 00:00:13
# 35 2019-04-01 00:00:14
#                        대여일시
# 1427453 2019-04-30 23:59:40
# 1427762 2019-04-30 23:59:49
# 1427585 2019-04-30 23:59:52
#                     대여일시
# 2196 2019-05-01 00:00:00
# 938  2019-05-01 00:00:02
# 10   2019-05-01 00:00:04
# ...

# %% [markdown]
# ## 4. concat

# %%
rental_19_06 = pd.concat([rental_19_06_1, rental_19_06_2, rental_19_06_3])
rental_19_07 = pd.concat([rental_19_07_1, rental_19_07_2, rental_19_07_3])
rental_19_08 = pd.concat([rental_19_08_1, rental_19_08_2, rental_19_08_3])
rental_19_09 = pd.concat([rental_19_09_1, rental_19_09_2, rental_19_09_3])
rental_19_10 = pd.concat([rental_19_10_1, rental_19_10_2, rental_19_10_3])
rental_19_11 = pd.concat([rental_19_11_1, rental_19_11_2])

# %%
rental_20_01_31 = rental_20_02.query("대여일시 >= '2020-01-31' and 대여일시 <'2020-02-01'")
rental_20_02_29 = rental_20_03.query("대여일시 >= '2020-02-29' and 대여일시 <'2020-03-01'")
rental_20_03_31 = rental_20_04.query("대여일시 >= '2020-03-31' and 대여일시 <'2020-04-01'")
rental_20_04_30 = rental_20_05.query("대여일시 >= '2020-04-30' and 대여일시 <'2020-05-01'")
rental_20_07 = rental_20_0708.query("대여일시 >= '2020-07-01' and 대여일시 <'2020-08-01'")
rental_20_08 = rental_20_0708.query("대여일시 >= '2020-08-01' and 대여일시 <'2020-09-01'")

# %%
rental_20_01 = pd.concat([rental_20_01, rental_20_01_31])
rental_20_02 = pd.concat([rental_20_02, rental_20_02_29])
rental_20_03 = pd.concat([rental_20_03, rental_20_03_31])
rental_20_04 = pd.concat([rental_20_04, rental_20_04_30])

# %%
rental_20_02 = rental_20_02.query("대여일시 >= '2020-02-01' and 대여일시 <'2020-03-01'")
rental_20_03 = rental_20_03.query("대여일시 >= '2020-03-01' and 대여일시 <'2020-04-01'")
rental_20_04 = rental_20_04.query("대여일시 >= '2020-04-01' and 대여일시 <'2020-05-01'")
rental_20_05 = rental_20_05.query("대여일시 >= '2020-05-01' and 대여일시 <'2020-06-01'")

# %%
rental_dataset_new = [rental_19_01, rental_19_02, rental_19_03, rental_19_04, rental_19_05,
                      rental_19_06, rental_19_07, rental_19_08, rental_19_09, rental_19_10,
                      rental_19_11, rental_19_12, rental_20_01, rental_20_02, rental_20_03,
                      rental_20_04, rental_20_05, rental_20_06, rental_20_07, rental_20_08,
                      rental_20_09, rental_20_10, rental_20_11, rental_20_12, rental_21_01]

# %% [markdown]
# ## 5. final test

# %%
for i in rental_dataset_new:
    i = i.sort_values("대여일시")
    print(i.iloc[:,[1]].head(3))
    print(i.iloc[:,[1]].tail(3))
# Out:
#                   대여일시
# 70 2019-01-01 00:00:01
# 34 2019-01-01 00:00:07
# 0  2019-01-01 00:00:44
#                       대여일시
# 485666 2019-01-31 23:59:36
# 485680 2019-01-31 23:59:40
# 485652 2019-01-31 23:59:49
#                   대여일시
# 98 2019-02-01 00:00:08
# 2  2019-02-01 00:00:11
# 16 2019-02-01 00:00:21
#                       대여일시
# 461898 2019-02-28 23:59:54
# 461744 2019-02-28 23:59:57
# 461805 2019-02-28 23:59:59
#                    대여일시
# 0   2019-03-01 00:00:04
# 15  2019-03-01 00:00:07
# 211 2019-03-01 00:00:19
#                       대여일시
# 885050 2019-03-31 23:59:54
# 885013 2019-03-31 23:59:59
# 884958 2019-03-31 23:59:59
#                   대여일시
# 0  2019-04-01 00:00:07
# 9  2019-04-01 00:00:13
# 35 2019-04-01 00:00:14
#                        대여일시
# 1427453 2019-04-30 23:59:40
# 1427762 2019-04-30 23:59:49
# 1427585 2019-04-30 23:59:52
#                     대여일시
# 2196 2019-05-01 00:00:00
# 938  2019-05-01 00:00:02
# 10   2019-05-01 00:00:04
# ...

# %% [markdown]
# ## 6. save file

# %%
rental_19_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_01.csv', encoding = 'cp949')
rental_19_02.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_02.csv', encoding = 'cp949')
rental_19_03.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_03.csv', encoding = 'cp949')
rental_19_04.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_04.csv', encoding = 'cp949')
rental_19_05.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_05.csv', encoding = 'cp949')
rental_19_06.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_06.csv', encoding = 'cp949')
rental_19_07.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_07.csv', encoding = 'cp949')
rental_19_08.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_08.csv', encoding = 'cp949')
rental_19_09.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_09.csv', encoding = 'cp949')
rental_19_10.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_10.csv', encoding = 'cp949')
rental_19_11.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_11.csv', encoding = 'cp949')
rental_19_12.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_19_12.csv', encoding = 'cp949')

rental_20_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_01.csv', encoding = 'cp949')
rental_20_02.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_02.csv', encoding = 'cp949')
rental_20_03.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_03.csv', encoding = 'cp949')
rental_20_04.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_04.csv', encoding = 'cp949')
rental_20_05.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_05.csv', encoding = 'cp949')
rental_20_06.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_06.csv', encoding = 'cp949')
rental_20_07.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_07.csv', encoding = 'cp949')
rental_20_08.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_08.csv', encoding = 'cp949')
rental_20_09.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_09.csv', encoding = 'cp949')
rental_20_10.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_10.csv', encoding = 'cp949')
rental_20_11.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_11.csv', encoding = 'cp949')
rental_20_12.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_20_12.csv', encoding = 'cp949')

rental_21_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_21_01.csv', encoding = 'cp949')

# %%
rental_data_2019 = pd.concat([rental_19_01, rental_19_02, rental_19_03, rental_19_04, rental_19_05, rental_19_06,
                            rental_19_07, rental_19_08, rental_19_09, rental_19_10, rental_19_11, rental_19_12])
rental_data_2020 = pd.concat([rental_20_01, rental_20_02, rental_20_03, rental_20_04, rental_20_05, rental_20_06,
                            rental_20_07, rental_20_08, rental_20_09, rental_20_10, rental_20_11, rental_20_12])

# %%
rental_data_2019.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2019.csv', encoding = 'cp949')
rental_data_2020.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2020.csv', encoding = 'cp949')

# %%
rental_data_2020
# Out:
#              자전거번호                대여일시  대여 대여소번호            대여 대여소명 대여거치대  \
# 20       SPB-16682 2020-01-01 00:00:09      1373         성북구보건소 건너편     1
# 76       SPB-10534 2020-01-01 00:00:53       173        서대문역 8번출구 앞     3
# 0        SPB-04061 2020-01-01 00:01:04       429               송도병원     2
# 4        SPB-09038 2020-01-01 00:01:11      1168        마곡엠밸리10단지 앞     5
# 14       SPB-12414 2020-01-01 00:01:15      3533   건대입구역 사거리(롯데백화점)     3
# ...            ...                 ...       ...                ...   ...
# 1185902  SPB-32746 2020-12-31 20:36:25      1009     천호역4번출구(현대백화점)     0
# 1185903  SPB-30390 2020-12-31 22:51:36      1965    삼환로즈빌아파트 105동 옆     0
# 1185904  SPB-50439 2020-12-31 22:56:32      1964            원메디타운 앞     0
# 1185905  SPB-37080 2020-12-31 22:18:07       130    신촌역(2호선) 7번출구 앞     0
# 1185906  SPB-33700 2020-12-31 21:52:24      1735  도봉역 1,2번 출구사이 건너편     0
#
#                         반납일시 반납대여소번호          반납대여소명  반납거치대   이용시간      이용거리
# ...

# %%
ride_data_2020
# Out:
#               대여일자  대여시간  대여소번호                대여소명 대여구분코드   성별 연령대코드  이용건수  \
# 776956  2020-01-01     0   1044         1044. 굽은다리역    정기권  NaN  ~10대     1
# 776957  2020-01-01     0   1656  1656. 중앙하이츠 아파트 입구    정기권  NaN  ~10대     1
# 776958  2020-01-01     0   1337        1337. 돈암성당 옆    정기권  NaN  ~10대     1
# 776959  2020-01-01     0   1984          1984. 구로구청    정기권  NaN  ~10대     1
# 776960  2020-01-01     0   2601    2601. 석촌호수 서호사거리    정기권  NaN  ~10대     1
# ...            ...   ...    ...                 ...    ...  ...   ...   ...
# 1066896 2020-12-31    23   3121          3121.가좌삼거리    일일권    M   30대     1
# 1066897 2020-12-31    23    560         560. 비전교회 앞    일일권    M   30대     1
# 1066898 2020-12-31    23   1416      1416. 상봉역 3번출구    일일권    M   30대     1
# 1066899 2020-12-31    23   1625     1625. 상계역(4번출구)    일일권    M   50대     1
# 1066900 2020-12-31    23    419         419. 홈플러스 앞    단체권  NaN   20대     4
#
#            운동량   탄소량     이동거리  사용시간
# ...

# %% [markdown]
# # 공공자전거 이용정보 (시간대별)

# %% [markdown]
# ## 1. data

# %%
ride_18_12_19_05_1 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_1.csv', encoding = 'cp949')
ride_18_12_19_05_2 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_2.csv', encoding = 'cp949')
ride_18_12_19_05_3 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_3.csv', encoding = 'cp949')
ride_18_12_19_05_4 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_4.csv', encoding = 'cp949')
ride_18_12_19_05_5 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_5.csv', encoding = 'cp949')
ride_18_12_19_05_6 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_18.12_19.05_6.csv', encoding = 'cp949')

ride_19_06_19_11_1 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_1.csv', encoding = 'cp949')
ride_19_06_19_11_2 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_2.csv', encoding = 'cp949')
ride_19_06_19_11_3 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_3.csv', encoding = 'cp949')
ride_19_06_19_11_4 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_4.csv', encoding = 'cp949')
ride_19_06_19_11_5 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_5.csv', encoding = 'cp949')
ride_19_06_19_11_6 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_6.csv', encoding = 'cp949')
ride_19_06_19_11_7 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_7.csv', encoding = 'cp949')
ride_19_06_19_11_8 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_8.csv', encoding = 'cp949')
ride_19_06_19_11_9 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_9.csv', encoding = 'cp949')
ride_19_06_19_11_10 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.06_19.11_10.csv', encoding = 'cp949')
ride_19_12_20_05 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_19.12_20.05.csv', encoding = 'cp949')

ride_20_06 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.06.csv', encoding = 'cp949')
ride_20_07 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.07.csv', encoding = 'cp949')
ride_20_08 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.08.csv', encoding = 'cp949')
ride_20_09 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.09.csv', encoding = 'cp949')
ride_20_10 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.10.csv', encoding = 'cp949')
ride_20_11 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.11.csv', encoding = 'cp949')
ride_20_12 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_20.12.csv', encoding = 'cp949')
ride_21_01 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/공공자전거 이용정보(시간대별)_21.01.csv', encoding = 'cp949')
# Out:
# /Users/hyomin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## 2. column name 확인

# %%
ride_dataset = [ride_18_12_19_05_1, ride_18_12_19_05_2, ride_18_12_19_05_3, ride_18_12_19_05_4,
                ride_18_12_19_05_5, ride_18_12_19_05_6, ride_19_06_19_11_1, ride_19_06_19_11_2,
                ride_19_06_19_11_3, ride_19_06_19_11_4, ride_19_06_19_11_5, ride_19_06_19_11_6,
                ride_19_06_19_11_7, ride_19_06_19_11_8, ride_19_06_19_11_9, ride_19_06_19_11_10,
               ride_19_12_20_05, ride_20_06, ride_20_07, ride_20_08, ride_20_09, ride_20_10,
               ride_20_11, ride_20_12, ride_21_01]

# %%
for i in ride_dataset:
    print(i.columns[0:])
# Out:
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# Index(['대여일자', '대여시간', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량',
#        '탄소량', '이동거리', '사용시간'],
#       dtype='object')
# ...

# %% [markdown]
# ## 3. date

# %%
for i in ride_dataset:
    i['대여일자'] = pd.to_datetime(i["대여일자"])

# %%
for i in ride_dataset:
    i = i.sort_values("대여일자")
    print(i.iloc[:,[0]].head(3))
    print(i.iloc[:,[0]].tail(3))
# Out:
#             대여일자
# 0     2018-12-01
# 14754 2018-12-01
# 14753 2018-12-01
#              대여일자
# 992044 2019-02-27
# 992035 2019-02-27
# 999999 2019-02-27
#            대여일자
# 0    2019-04-13
# 8874 2019-04-13
# 8875 2019-04-13
#              대여일자
# 969049 2019-05-05
# 969051 2019-05-05
# 999999 2019-05-05
#            대여일자
# 0    2019-05-05
# 1384 2019-05-05
# 1383 2019-05-05
#              대여일자
# 989770 2019-05-24
# 989758 2019-05-24
# 999999 2019-05-24
#             대여일자
# 0     2019-05-24
# 29244 2019-05-24
# 29245 2019-05-24
#              대여일자
# 386135 2019-05-31
# 386122 2019-05-31
# 428525 2019-05-31
#             대여일자
# 0     2019-05-24
# 29244 2019-05-24
# 29245 2019-05-24
#              대여일자
# 386135 2019-05-31
# 386122 2019-05-31
# 428525 2019-05-31
#             대여일자
# 0     2019-02-27
# 10363 2019-02-27
# 10364 2019-02-27
#               대여일자
# 995818  2019-04-13
# 995810  2019-04-13
# 1025262 2019-04-13
#             대여일자
# 0     2019-06-01
# 39978 2019-06-01
# ...

# %% [markdown]
# ## 4. concat

# %%
ride_data1 = pd.concat([ride_18_12_19_05_1, ride_18_12_19_05_2, ride_18_12_19_05_3, ride_18_12_19_05_4,
                        ride_18_12_19_05_5, ride_18_12_19_05_6])
ride_data2 = pd.concat([ride_19_06_19_11_1, ride_19_06_19_11_2, ride_19_06_19_11_3, ride_19_06_19_11_4,
                        ride_19_06_19_11_5, ride_19_06_19_11_6, ride_19_06_19_11_7, ride_19_06_19_11_8,
                        ride_19_06_19_11_9, ride_19_06_19_11_10, ride_19_12_20_05])

# %%
ride_19_01 = ride_data1.query("대여일자 >= '2019-01-01' and 대여일자 <'2019-02-01'")
ride_19_02 = ride_data1.query("대여일자 >= '2019-02-01' and 대여일자 <'2019-03-01'")
ride_19_03 = ride_data1.query("대여일자 >= '2019-03-01' and 대여일자 <'2019-04-01'")
ride_19_04 = ride_data1.query("대여일자 >= '2019-04-01' and 대여일자 <'2019-05-01'")
ride_19_05 = ride_data1.query("대여일자 >= '2019-05-01' and 대여일자 <'2019-06-01'")
ride_19_06 = ride_data2.query("대여일자 >= '2019-06-01' and 대여일자 <'2019-07-01'")
ride_19_07 = ride_data2.query("대여일자 >= '2019-07-01' and 대여일자 <'2019-08-01'")
ride_19_08 = ride_data2.query("대여일자 >= '2019-08-01' and 대여일자 <'2019-09-01'")
ride_19_09 = ride_data2.query("대여일자 >= '2019-09-01' and 대여일자 <'2019-10-01'")
ride_19_10 = ride_data2.query("대여일자 >= '2019-10-01' and 대여일자 <'2019-11-01'")
ride_19_11 = ride_data2.query("대여일자 >= '2019-11-01' and 대여일자 <'2019-12-01'")
ride_19_12 = ride_data2.query("대여일자 >= '2019-12-01' and 대여일자 <'2020-01-01'")
ride_20_01 = ride_data2.query("대여일자 >= '2020-01-01' and 대여일자 <'2020-02-01'")
ride_20_02 = ride_data2.query("대여일자 >= '2020-02-01' and 대여일자 <'2020-03-01'")
ride_20_03 = ride_data2.query("대여일자 >= '2020-03-01' and 대여일자 <'2020-04-01'")
ride_20_04 = ride_data2.query("대여일자 >= '2020-04-01' and 대여일자 <'2020-05-01'")
ride_20_05 = ride_data2.query("대여일자 >= '2020-05-01' and 대여일자 <'2020-06-01'")

# %%
ride_dataset_new = [ride_19_01, ride_19_02, ride_19_03, ride_19_04, ride_19_05, ride_19_06, 
                    ride_19_07, ride_19_08, ride_19_09, ride_19_10, ride_19_11, ride_19_12,
                    ride_20_01, ride_20_02, ride_20_03, ride_20_04, ride_20_05, ride_20_06,
                    ride_20_07, ride_20_08, ride_20_09, ride_20_10, ride_20_11, ride_20_12, ride_21_01]

# %% [markdown]
# ## 5. final test

# %%
for i in ride_dataset_new:
    i = i.sort_values("대여일자")
    print(i)
# Out:
#              대여일자  대여시간  대여소번호              대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 460036 2019-01-01     0    458    458. 광화문역 5번출구    정기권  F  ~10대     1
# 463528 2019-01-01    16    912        912. 응암오거리    일일권  M   20대     1
# 463527 2019-01-01    16    907      907. CJ 드림시티    일일권  M   20대     1
# 463526 2019-01-01    16    818  818. 숙명여대 입구 교차로    일일권  M   20대     1
# 463525 2019-01-01    16    134      134. 연세로 명물길    일일권  M   20대     1
# ...           ...   ...    ...               ...    ... ..   ...   ...
# 745854 2019-01-31     9   1115   1115. 등촌역 1번출구옆    정기권  M   20대     1
# 745855 2019-01-31     9   1212  1212. 송파역 2번 출구앞    정기권  M   20대     1
# 745856 2019-01-31     9   1416    1416. 상봉역 3번출구    정기권  M   20대     1
# 745838 2019-01-31     9    223    223. 진주아파트상가 앞    정기권  M   20대     1
# 752767 2019-01-31    23   2177  2177. 신대방역 2번 출구    일일권  M   40대     1
#
#            운동량   탄소량     이동거리  사용시간
# 460036   41.96  0.38   1630.0    29
# 463528  345.53  3.21  13850.0   115
# ...

# %% [markdown]
# ## 6. save

# %%
ride_19_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_01.csv', encoding = 'cp949')
ride_19_02.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_02.csv', encoding = 'cp949')
ride_19_03.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_03.csv', encoding = 'cp949')
ride_19_04.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_04.csv', encoding = 'cp949')
ride_19_05.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_05.csv', encoding = 'cp949')
ride_19_06.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_06.csv', encoding = 'cp949')
ride_19_07.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_07.csv', encoding = 'cp949')
ride_19_08.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_08.csv', encoding = 'cp949')
ride_19_09.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_09.csv', encoding = 'cp949')
ride_19_10.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_10.csv', encoding = 'cp949')
ride_19_11.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_11.csv', encoding = 'cp949')
ride_19_12.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_19_12.csv', encoding = 'cp949')

ride_20_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_01.csv', encoding = 'cp949')
ride_20_02.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_02.csv', encoding = 'cp949')
ride_20_03.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_03.csv', encoding = 'cp949')
ride_20_04.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_04.csv', encoding = 'cp949')
ride_20_05.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_05.csv', encoding = 'cp949')
ride_20_06.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_06.csv', encoding = 'cp949')
ride_20_07.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_07.csv', encoding = 'cp949')
ride_20_08.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_08.csv', encoding = 'cp949')
ride_20_09.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_09.csv', encoding = 'cp949')
ride_20_10.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_10.csv', encoding = 'cp949')
ride_20_11.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_11.csv', encoding = 'cp949')
ride_20_12.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_20_12.csv', encoding = 'cp949')

ride_21_01.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_21_01.csv', encoding = 'cp949')

# %%
ride_data_2019 = pd.concat([ride_19_01, ride_19_02, ride_19_03, ride_19_04, ride_19_05, ride_19_06,
                            ride_19_07, ride_19_08, ride_19_09, ride_19_10, ride_19_11, ride_19_12])
ride_data_2020 = pd.concat([ride_20_01, ride_20_02, ride_20_03, ride_20_04, ride_20_05, ride_20_06,
                            ride_20_07, ride_20_08, ride_20_09, ride_20_10, ride_20_11, ride_20_12])

# %%
ride_data_2019.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2019.csv', encoding = 'cp949')
ride_data_2020.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2020.csv', encoding = 'cp949')

# %% [markdown]
# # change column names

# %%
rental_data_2019 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2019.csv", encoding='cp949')
rental_data_2020 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2020.csv", encoding='cp949')
rental_data_2021 = pd.read_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_21_01.csv", encoding='cp949')
ride_data_2019 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2019.csv', encoding = 'cp949')
ride_data_2020 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2020.csv', encoding = 'cp949')
ride_data_2021 = pd.read_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_21_01.csv', encoding = 'cp949')
# Out:
# /Users/hyomin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/hyomin/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rental_data_2019.rename(columns = {'자전거번호' : 'bike_no','대여일시' : 'rental_date','대여 대여소번호' : 'rental_loc_no',
                                  '대여 대여소명' : 'rental_loc_name','대여거치대' : 'rental_rack','반납일시' : 'return_date',
                                  '반납대여소번호' : 'return_loc_no','반납대여소명' : 'return_loc_name','반납거치대' : 'return_rack',
                                  '이용시간' : 'rental_time','이용거리' : 'rental_distance'}, inplace = True)
rental_data_2020.rename(columns = {'자전거번호' : 'bike_no','대여일시' : 'rental_date','대여 대여소번호' : 'rental_loc_no',
                                  '대여 대여소명' : 'rental_loc_name','대여거치대' : 'rental_rack','반납일시' : 'return_date',
                                  '반납대여소번호' : 'return_loc_no','반납대여소명' : 'return_loc_name','반납거치대' : 'return_rack',
                                  '이용시간' : 'rental_time','이용거리' : 'rental_distance'}, inplace = True)
rental_data_2021.rename(columns = {'자전거번호' : 'bike_no','대여일시' : 'rental_date','대여 대여소번호' : 'rental_loc_no',
                                  '대여 대여소명' : 'rental_loc_name','대여거치대' : 'rental_rack','반납일시' : 'return_date',
                                  '반납대여소번호' : 'return_loc_no','반납대여소명' : 'return_loc_name','반납거치대' : 'return_rack',
                                  '이용시간' : 'rental_time','이용거리' : 'rental_distance'}, inplace = True)

ride_data_2019.rename(columns = {'대여일자' : 'date','대여시간' : 'time','대여소번호' : 'location_num',
                                  '대여소명' : 'location_name','대여구분코드' : 'rental_code','성별' : 'sex',
                                  '연령대코드' : 'age','이용건수' : 'usage','운동량' : 'calories',
                                  '탄소량' : 'carbon','이동거리' : 'distance','사용시간' : 'usage_time'}, inplace = True)
ride_data_2020.rename(columns = {'대여일자' : 'date','대여시간' : 'time','대여소번호' : 'location_num',
                                  '대여소명' : 'location_name','대여구분코드' : 'rental_code','성별' : 'sex',
                                  '연령대코드' : 'age','이용건수' : 'usage','운동량' : 'calories',
                                  '탄소량' : 'carbon','이동거리' : 'distance','사용시간' : 'usage_time'}, inplace = True)
ride_data_2021.rename(columns = {'대여일자' : 'date','대여시간' : 'time','대여소번호' : 'location_num',
                                  '대여소명' : 'location_name','대여구분코드' : 'rental_code','성별' : 'sex',
                                  '연령대코드' : 'age','이용건수' : 'usage','운동량' : 'calories',
                                  '탄소량' : 'carbon','이동거리' : 'distance','사용시간' : 'usage_time'}, inplace = True)

# %%
rental_data_2019.to_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2019.csv", encoding='cp949')
rental_data_2020.to_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2020.csv", encoding='cp949')
rental_data_2021.to_csv("/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_대여이력_정보/rental_data_2021.csv", encoding='cp949')
ride_data_2019.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2019.csv', encoding = 'cp949')
ride_data_2020.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2020.csv', encoding = 'cp949')
ride_data_2021.to_csv('/Volumes/GoogleDrive/공유 드라이브/빅분기C조/ju_notes/data/공공자전거_이용정보(시간대별)/ride_data_2021.csv', encoding = 'cp949')
